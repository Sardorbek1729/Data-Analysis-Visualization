# %% [markdown]
# # Countplot

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.countplot(data=penguins, x="species");

# %%
sns.countplot(data=penguins, x="species", hue="sex");

# %%
titanic = pd.read_csv("data/titanic.csv")

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
sns.countplot(data=titanic, x="pclass", hue="sex");

# %% [markdown]
# # Stripplot & Swarmplot

# %%
taxis = sns.load_dataset("taxis")

# %%
taxis
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %%
sns.scatterplot(data=taxis, x="pickup_borough", y="distance");

# %%
sns.stripplot(data=taxis, x="pickup_borough", y="distance");

# %%
taxis_sample = taxis.nlargest(600, "total")

# %%
plt.figure(figsize=(12, 5))
sns.swarmplot(data=taxis_sample, x="pickup_borough", y="distance");

# %%
sns.stripplot(data=taxis_sample, x="pickup_borough", y="distance");

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
plt.figure(figsize=(12, 5))
sns.swarmplot(data=titanic, x="pclass", y="age");

# %%
plt.figure(figsize=(12, 5))
sns.swarmplot(data=titanic, x="pclass", y="age", hue="sex");

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(data=titanic, x="age");

# %%
sns.boxplot(data=taxis, x="pickup_borough", y="total");

# %%
sns.boxplot(data=taxis, x="pickup_borough", y="total", whis=2.5);

# %%
sns.boxplot(data=titanic, x="pclass", y="age");

# %%
sns.boxplot(data=titanic, x="pclass", y="age", hue="sex");

# %%
sns.boxplot(data=titanic, x="pclass", y="age", hue="sex", fliersize=2);

# %%
sns.boxplot(data=penguins, x="species", y="body_mass_g");

# %%
sns.swarmplot(data=penguins, x="species", y="body_mass_g", color="0.3");

# %%
sns.boxplot(data=penguins, x="species", y="body_mass_g")
sns.swarmplot(data=penguins, x="species", y="body_mass_g", color="0.3");

# %% [markdown]
# # Boxenplot

# %%
sns.boxplot(data=taxis, x="pickup_borough", y="total");

# %%
plt.figure(figsize=(7, 6))
sns.boxenplot(data=taxis, x="pickup_borough", y="total");

# %% [markdown]
# # Violinplot

# %%
sns.violinplot(data=titanic, x="age")
sns.boxplot(data=titanic, x="age");

# %%
sns.violinplot(data=titanic, x="pclass", y="age");

# %%
sns.violinplot(data=titanic, x="pclass", y="age", hue="sex");

# %%
sns.violinplot(data=titanic, x="pclass", y="age", hue="sex", split=True);

# %% [markdown]
# # Barplot

# %%
taxis
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %%
sns.barplot(data=taxis, x="pickup_borough", y="distance");

# %%
sns.barplot(data=taxis, x="pickup_borough", y="total");

# %%
sns.barplot(data=taxis, x="pickup_borough", y="total", estimator=sum);

# %%
sns.barplot(data=taxis, x="pickup_borough", y="total", hue="color");

# %%
sns.barplot(data=taxis, x="pickup_borough", y="distance", hue="color");

# %%
plt.figure(figsize=(7, 5))
sns.violinplot(data=taxis, x="pickup_borough", y="distance", hue="color", split=True);

# %%
sns.barplot(data=taxis, x="pickup_borough", y="distance", hue="color", dodge=False);

# %%
sns.barplot(data=titanic, x="pclass", y="survived");

# %% [markdown]
# # Catplot

# %%
sns.catplot(data=titanic, x="sex", y="survived", kind="bar");

# %%
sns.catplot(data=titanic, x="sex", y="survived", kind="bar", col="pclass");

# %%
sns.catplot(data=titanic, x="pclass", y="survived", kind="bar", hue="sex");

# %%
sns.catplot(data=taxis, x="pickup_borough", y="total", kind="point", col="color");

# %%
sns.catplot(data=taxis, x="pickup_borough", y="total", kind="violin", hue="color", split=True);

# %%
sns.catplot(data=titanic, x="who", y="survived", kind="bar", col="pclass", ci=None, row="embarked");
